# %% [markdown]
# Question:1
# Write a function that stutters a word as if someone is struggling to read it. The first two letters are repeated twice with an ellipsis ... and space after each, and then the word is pronounced with a question mark?.
# Examples
# stutter("incredible") = "in... in... incredible?"
# stutter("enthusiastic")= "en... en... enthusiastic?"
# stutter("outstanding")= "ou... ou... outstanding?"

# %%
def stutter(text):
    print(f"{text[:2]}... {text[:2]}... {text}?")

# %%
text=input("enter the text:")
stutter(text)
# Out:
# enter the text: incredible
# in... in... incredible?

# %%
text=input("enter the text:")
stutter(text)
# Out:
# enter the text: enthusiastic
# en... en... enthusiastic?

# %%
text=input("enter the text:")
stutter(text)
# Out:
# enter the text: outstanding
# ou... ou... outstanding?

# %% [markdown]
# Question 2: Create a function that takes an angle in radians and returns the corresponding angle in degrees rounded to one decimal place.

# %%
def radians_to_degrees(radians):
    return round((radians * 57.3),1)

# %%
radians_to_degrees(1)
# Out:
# 57.3

# %%
radians_to_degrees(20)
# Out:
# 1146.0

# %%
radians_to_degrees(50)
# Out:
# 2865.0

# %% [raw]
# Question 3:
# In this challenge, establish if a given integer num is a Curzon number. If 1 plus 2 elevated to num is exactly divisible by 1 plus 2 multiplied by num, then num is a Curzon number.
#
# Examples:
# is_curzon(5)=True
# # 2**5+1=33
# # 2*5+1=11
# # 33 is multiple of 11
#
# is_curzon(10)= False
# #2**10+1=1025
# #2*10+1=21
# #1025 is not a multiple of 21

# %%
def is_curzon(n):
    val1=2**n+1
    val2=2*n+1
    if val1%val2==0:
        print("True")
    else:
        print("False")

# %%
n=int(input("enter the number:"))
is_curzon(n)
# Out:
# enter the number: 5
# True

# %%
n=int(input("enter the number:"))
is_curzon(n)
# Out:
# enter the number: 10
# False

# %% [markdown]
# Question-4:
# Given the side length x find the area of a hexagon
#
# Formula:
# A=(3*sqrt(3)*s**2)/2
#
# Examples:
# area_of_hexagon(1)=2.6
# area_of_hexagon(2)=10.4
# area_of_hexagon(3)=23.4

# %%
import math as m
def area_of_hexagon(side):
    area=(3*(m.sqrt(3))*(side**2))/2
    return round(area,1)

# %%
side=int(input("enter the number:"))
area_of_hexagon(side)
# Out:
# enter the number: 1
# 2.6

# %%
side=int(input("enter the number:"))
area_of_hexagon(side)
# Out:
# enter the number: 2
# 10.4

# %%
side=int(input("enter the number:"))
area_of_hexagon(side)
# Out:
# enter the number: 3
# 23.4

# %% [raw]
# Question-5:
# Create a function that returns a base-2 (binary) representation of a base-10 (decimal) string number. To convert is simple:((2) means base-2 and (10) means base-10) 010101001(2)=1+8+32+128.
#
# Going from right to left, the value of the most right bit is 1, now from that every bit to the left will be x2 the value, value of 8-bit numbers are(256,128,64,32,16,8,4,2,1).
#
# Examples:
#
# binary(1) = "1"
# #1*1=1
#
# binary(5) = "101"
# #1*1+1*4=5
#
# binary(10)="1010"
# #1*2+1*8=10

# %%
def binary(n):
    value=bin(n)
    return value[2:]

# %%
binary(5)
# Out:
# '101'

# %%
binary(1)
# Out:
# '1'

# %%
binary(10)
# Out:
# '1010'

# %%
def binary(n):
    binary_value=""
    while n>0:
        binary_value+=str(n%2)
        n=int(n/2)
    return binary_value

# %%
binary(1)
# Out:
# '1'

# %%
binary(5)
# Out:
# '101'

# %%
binary(10)
# Out:
# '0101'
